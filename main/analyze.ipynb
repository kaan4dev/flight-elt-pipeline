# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/kaancakir/Library/CloudStorage/OneDrive-Kişisel/data/projects/flight-elt-pipeline/flights_transformed.csv')

# %%
average_delay_by_airline = df.groupby('airline_name')['departure_delay'].mean().sort_values(ascending=False)
print('Average delay time of airlines (per minute): ')
print(average_delay_by_airline)
# Out:
# Average delay time of airlines (per minute):
# airline_name
# TAP Air Portugal      54.000000
# Royal Jordanian       41.000000
# Delta Air Lines       37.666667
# SriLankan Airlines    35.500000
# Gulf Air              35.500000
# Air France            33.250000
# KLM                   33.250000
# Iberia                31.800000
# AlphaSky              31.800000
# Finnair               31.800000
# Malaysia Airlines     30.000000
# Aer Lingus            29.333333
# British Airways       29.166667
# Virgin Atlantic       26.600000
# American Airlines     23.600000
# JetBlue Airways       22.333333
# SAS                   20.000000
# Name: departure_delay, dtype: float64

# %%
flight_status_counts = df['flight_status'].value_counts()
print("Distrubution Of Flight Status: ")
print(flight_status_counts)
# Out:
# Distrubution Of Flight Status:
# flight_status
# landed       52
# scheduled     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.bar(average_delay_by_airline.index, average_delay_by_airline.values, color='skyblue')
plt.xticks(rotation=45)
plt.title('Average delay time of airlines')
plt.xlabel('Airline')
plt.ylabel('Average Delay per minute')
plt.tight_layout()
plt.show()
